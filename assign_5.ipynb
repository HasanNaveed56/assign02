# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
d1 = pd.read_csv('loan-train.csv')
d2 = pd.read_csv('adult.csv')
d3 = pd.read_csv('hotel_booking.csv')

# %%
d1.head(5)

# %%
d1.tail(5)

# %%
d1.shape

# %%
d1.info()

# %%
d1.describe()

# %%
d1.describe(include=object)

# %%
d1.dtypes

# %%
d1.isnull().sum()

# %%
d1.duplicated().sum()

# %%
d1.drop_duplicates(inplace=True)

# %%
for col in d1.columns:
    print(col)
    print(d1[col].unique())
    print("-"*40)

# %%
d1['Gender'].fillna(d1['Gender'].mode()[0], inplace=True)

# %%
d1['Gender'].fillna(d1['Married'].mode()[0], inplace=True)

# %%
d1['Gender'].fillna(d1['Dependents'].mode()[0], inplace=True)

# %%
d1['Gender'].fillna(d1['Self_Employed'].mode()[0], inplace=True)

# %%
d1['Gender'].fillna(d1['Loan_Amount_Term'].mode()[0], inplace=True)

# %%
d1['Gender'].fillna(d1['Credit_History'].mode()[0], inplace=True)

# %%
d1['Loan_Status'].value_counts()

# %%
d1['Loan_Status'].value_counts()

# %%
plt.figure(figsize=(8,5))
plt.hist(d1['ApplicantIncome'],bins=30)
plt.title("Applicant Income Distribution")
plt.xlabel("Income")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(d1['ApplicantIncome'],bins=30)
plt.title("Applicant Income Distribution")
plt.xlabel("Income")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(d1['LoanAmount'],bins=30,kde=True)
plt.show()

# %%
sns.boxplot(x=d1['LoanAmount'])
plt.show()

# %%
sns.countplot(x='Credit_History',data=d1)
plt.show()

# %%
sns.countplot(x='Education',data=d1)
plt.show()

# %%
sns.countplot(x='Gender',data=d1)
plt.show()

# %%
sns.countplot(x='Property_Area',data=d1)
plt.show()

# %%
sns.countplot(x='Self_Employed',data=d1)
plt.show()

# %%
sns.countplot(x='Credit_History',hue='Loan_Status',data=d1)
plt.show()

# %%
sns.countplot(x='Married',hue='Loan_Status',data=d1)
plt.show()

# %%
sns.countplot(x='Property_Area',hue='Loan_Status',data=d1)
plt.show()

# %%
sns.countplot(x='Self_Employed',hue='Loan_Status',data=d1)
plt.show()

# %%
sns.boxplot(x='Loan_Status',y='ApplicantIncome',data=d1)
plt.show()

# %%
sns.boxplot(x='Loan_Status',y='LoanAmount',data=d1)
plt.show()

# %%
sns.scatterplot(x='ApplicantIncome',y='LoanAmount',data=d1)
plt.show()

# %%
sns.scatterplot(x='CoapplicantIncome',y='LoanAmount',data=d1)
plt.show()

# %%
sns.pairplot(d1)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(d1.corr(numeric_only=True),annot=True,cmap='coolwarm')
plt.show()

# %%
sns.boxplot(x=d1['LoanAmount'])
plt.show()

# %%
d1['ApplicantIncome'].mean()
# Out:
# np.float64(8746.304832713755)

# %%
d1['ApplicantIncome'].max()
# Out:
# 81000

# %%
d1['ApplicantIncome'].min()
# Out:
# 150

# %%
d1["ID"] = range(1, len(d1)+1)
d2["ID"] = range(1, len(d2)+1)
d3["ID"] = range(1, len(d3)+1)

# %%
loan_adult = pd.merge(
    d1,
    d2,
    on="ID",
    how="inner"
)

loan_adult.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  ...  \
# 0             5849                0.0         NaN             360.0  ...
# 1             4583             1508.0       128.0             360.0  ...
# 2             3000                0.0        66.0             360.0  ...
# 3             2583             2358.0       120.0             360.0  ...
# 4             6000                0.0       141.0             360.0  ...
#
#        marital-status         occupation relationship   race  gender  \
# ...

# %%
loan_hotel = pd.merge(
    d1,
    d3,
    on="ID",
    how="inner"
)

loan_hotel.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  ...  \
# 0             5849                0.0         NaN             360.0  ...
# 1             4583             1508.0       128.0             360.0  ...
# 2             3000                0.0        66.0             360.0  ...
# 3             2583             2358.0       120.0             360.0  ...
# 4             6000                0.0       141.0             360.0  ...
#
#    customer_type   adr required_car_parking_spaces  total_of_special_requests  \
# ...

# %%
adult_hotel = pd.merge(
    d2,
    d3,
    on="ID",
    how="inner"
)

adult_hotel.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  ...  customer_type   adr  \
# 0  Machine-op-inspct    Own-child  Black    Male  ...      Transient   0.0
# 1    Farming-fishing      Husband  White    Male  ...      Transient   0.0
# 2    Protective-serv      Husband  White    Male  ...      Transient  75.0
# 3  Machine-op-inspct      Husband  Black    Male  ...      Transient  75.0
# 4                  ?    Own-child  White  Female  ...      Transient  98.0
#
# ...

# %%
concat_rows = pd.concat([d1.reset_index(), d2.reset_index()], axis=0)

concat_rows.head()
# Out:
#    index   Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0      0  LP001002   Male      No          0      Graduate            No
# 1      1  LP001003   Male     Yes          1      Graduate            No
# 2      2  LP001005   Male     Yes          0      Graduate           Yes
# 3      3  LP001006   Male     Yes          0  Not Graduate            No
# 4      4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  ...  marital-status  \
# 0           5849.0                0.0         NaN  ...             NaN
# 1           4583.0             1508.0       128.0  ...             NaN
# 2           3000.0                0.0        66.0  ...             NaN
# 3           2583.0             2358.0       120.0  ...             NaN
# 4           6000.0                0.0       141.0  ...             NaN
#
#    occupation relationship race  gender  capital-gain capital-loss  \
# ...

# %%
concat_cols = pd.concat([d1.reset_index(), d2.reset_index()], axis=1)

concat_cols.head()
# Out:
#    index   Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    0.0  LP001002   Male      No          0      Graduate            No
# 1    1.0  LP001003   Male     Yes          1      Graduate            No
# 2    2.0  LP001005   Male     Yes          0      Graduate           Yes
# 3    3.0  LP001006   Male     Yes          0  Not Graduate            No
# 4    4.0  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  ...         occupation  \
# 0           5849.0                0.0         NaN  ...  Machine-op-inspct
# 1           4583.0             1508.0       128.0  ...    Farming-fishing
# 2           3000.0                0.0        66.0  ...    Protective-serv
# 3           2583.0             2358.0       120.0  ...  Machine-op-inspct
# 4           6000.0                0.0       141.0  ...                  ?
#
#    relationship   race  gender  capital-gain  capital-loss  hours-per-week  \
# ...
